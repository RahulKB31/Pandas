# %% [markdown]
# # Pandas Task 4

# %%
#https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/datasets.csv

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/datasets.csv')

# %%
df
# Out:
#      Package           Item  \
# 0        AER        Affairs
# 1        AER   ArgentinaCPI
# 2        AER      BankWages
# 3        AER  BenderlyZwick
# 4        AER      BondYield
# ...      ...            ...
# 1709     vcd       UKSoccer
# 1710     vcd   VisualAcuity
# 1711     vcd        VonBort
# 1712     vcd     WeldonDice
# 1713     vcd     WomenQueue
#
#                                                   Title  Rows  Cols  n_binary  \
# 0                      Fair's Extramarital Affairs Data   601     9         2
# 1                     Consumer Price Index in Argentina    80     2         0
# 2                                            Bank Wages   474     4         2
# 3     Benderly and Zwick Data: Inflation, Growth and...    31     5         0
# 4                                       Bond Yield Data    60     2         0
# ...                                                 ...   ...   ...       ...
# ...

# %%
df.head(50)
# Out:
#    Package                Item  \
# 0      AER             Affairs
# 1      AER        ArgentinaCPI
# 2      AER           BankWages
# 3      AER       BenderlyZwick
# 4      AER           BondYield
# 5      AER     CartelStability
# 6      AER           CASchools
# 7      AER         ChinaIncome
# 8      AER         CigarettesB
# 9      AER        CigarettesSW
# 10     AER     CollegeDistance
# 11     AER        ConsumerGood
# 12     AER             CPS1985
# 13     AER             CPS1988
# 14     AER             CPSSW04
# 15     AER              CPSSW3
# 16     AER              CPSSW8
# 17     AER           CPSSW9204
# 18     AER           CPSSW9298
# 19     AER      CPSSWEducation
# 20     AER          CreditCard
# 21     AER           DJFranses
# 22     AER            DJIA8012
# 23     AER        DoctorVisits
# 24     AER         DutchAdvert
# 25     AER          DutchSales
# 26     AER     Electricity1955
# 27     AER     Electricity1970
# 28     AER   EquationCitations
# ...

# %%
df.tail(50)
# Out:
#      Package             Item  \
# 1664  texmex        wavesurge
# 1665  texmex           winter
# 1666   tidyr        billboard
# 1667   tidyr     construction
# 1668   tidyr  fish_encounters
# 1669   tidyr       population
# 1670   tidyr     relig_income
# 1671   tidyr           smiths
# 1672   tidyr           table1
# 1673   tidyr           table2
# 1674   tidyr           table3
# 1675   tidyr          table4a
# 1676   tidyr          table4b
# 1677   tidyr           table5
# 1678   tidyr   us_rent_income
# 1679   tidyr              who
# 1680   tidyr   world_bank_pop
# 1681     vcd        Arthritis
# 1682     vcd         Baseball
# 1683     vcd   BrokenMarriage
# 1684     vcd       Bundesliga
# 1685     vcd    Bundestag2005
# 1686     vcd        Butterfly
# 1687     vcd       CoalMiners
# 1688     vcd    DanishWelfare
# 1689     vcd       Employment
# 1690     vcd       Federalist
# 1691     vcd          Hitters
# 1692     vcd       HorseKicks
# 1693     vcd         Hospital
# ...

# %%
df.shape #It shows the the total no.rows and no. of columns of the frame
# Out:
# (1714, 12)

# %%
df.index #This attribute provides the index of the data frame
# Out:
# RangeIndex(start=0, stop=1714, step=1)

# %%
df.columns #It shows the name of each column
# Out:
# Index(['Package', 'Item', 'Title', 'Rows', 'Cols', 'n_binary', 'n_character',
#        'n_factor', 'n_logical', 'n_numeric', 'CSV', 'Doc'],
#       dtype='object')

# %%
df.dtypes #It shows the data type of each column
# Out:
# Package        object
# Item           object
# Title          object
# Rows            int64
# Cols            int64
# n_binary        int64
# n_character     int64
# n_factor        int64
# n_logical       int64
# n_numeric       int64
# CSV            object
# Doc            object
# dtype: object

# %%
df['Package'].unique()    #In a column it shows all the unique values.It can be applied on a single column only, not on the
                        #whole dataframe
# Out:
# array(['AER', 'boot', 'carData', 'causaldata', 'cluster', 'COUNT', 'DAAG',
#        'datasets', 'dplyr', 'dragracer', 'drc', 'Ecdat', 'evir',
#        'forecast', 'fpp2', 'gap', 'geepack', 'ggplot2', 'ggplot2movies',
#        'gt', 'HistData', 'HLMdiag', 'HSAUR', 'hwde', 'ISLR', 'KMsurv',
#        'lattice', 'lme4', 'lmec', 'MASS', 'mediation', 'mi', 'mosaicData',
#        'multgee', 'nycflights13', 'openintro', 'palmerpenguins', 'plm',
#        'plyr', 'pscl', 'psych', 'quantreg', 'reshape2', 'robustbase',
#        'rpart', 'sandwich', 'sem', 'Stat2Data', 'stevedata', 'survival',
#        'texmex', 'tidyr', 'vcd'], dtype=object)

# %%
df.nunique() #It shows the total no. of unique values in each column.It can be applied on a single
             #column as well as on whole dataframe
# Out:
# Package          53
# Item           1658
# Title          1580
# Rows            691
# Cols             56
# n_binary         27
# n_character      14
# n_factor         22
# n_logical         7
# n_numeric        51
# CSV            1714
# Doc            1714
# dtype: int64

# %%
df.count() #It shows the total no. of non-null in each column.
           #It can be applied on a single column as well as on whole dataframe
# Out:
# Package        1714
# Item           1714
# Title          1714
# Rows           1714
# Cols           1714
# n_binary       1714
# n_character    1714
# n_factor       1714
# n_logical      1714
# n_numeric      1714
# CSV            1714
# Doc            1714
# dtype: int64

# %%
df['Package'].value_counts() #In a column it shows all unique values with their count.
                             #It can be applied on single column only
# Out:
# Stat2Data         211
# openintro         198
# Ecdat             134
# DAAG              121
# AER               107
# MASS               87
# datasets           84
# stevedata          69
# carData            63
# boot               49
# HistData           46
# HSAUR              41
# robustbase         40
# fpp2               38
# drc                35
# causaldata         33
# vcd                33
# mosaicData         31
# KMsurv             27
# psych              23
# COUNT              21
# gap                18
# pscl               17
# tidyr              15
# plm                14
# survival           14
# ISLR               13
# ggplot2            11
# lme4               11
# cluster             9
# geepack             9
# quantreg            7
# lattice             7
# evir                7
# texmex              7
# rpart               6
# gt                  6
# mediation           6
# sem                 6
# dplyr               5
# nycflights13        5
# ...

# %%
df['Item'].value_counts()
# Out:
# Mroz                    3
# salinity                3
# Grunfeld                3
# smoking                 3
# housing                 3
#                        ..
# GermanUnemployment      1
# LongJumpOlympics2016    1
# sunspotarea             1
# MLBStandings2016        1
# BreesPass               1
# Name: Item, Length: 1658, dtype: int64

# %%
df['Title'].value_counts()
# Out:
# Internal functions for gap                      18
# Labour Training Evaluation Data                 11
# Seven data sets showing a bifactor solution.     9
# Stock and Watson CPS Data Sets                   6
# Example tabular representations                  6
#                                                 ..
# Passengers on the Titanic                        1
# Longley's Regression Data                        1
# medpar                                           1
# Plant Species Traits Data                        1
# Stock Market Data                                1
# Name: Title, Length: 1580, dtype: int64

# %%
df.info() #Provides basic data about dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1714 entries, 0 to 1713
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Package      1714 non-null   object
#  1   Item         1714 non-null   object
#  2   Title        1714 non-null   object
#  3   Rows         1714 non-null   int64
#  4   Cols         1714 non-null   int64
#  5   n_binary     1714 non-null   int64
#  6   n_character  1714 non-null   int64
#  7   n_factor     1714 non-null   int64
#  8   n_logical    1714 non-null   int64
#  9   n_numeric    1714 non-null   int64
#  10  CSV          1714 non-null   object
#  11  Doc          1714 non-null   object
# dtypes: int64(7), object(5)
# memory usage: 160.8+ KB

# %%
df.drop(['Package', 'Item', 'Title','CSV', 'Doc'],axis=1)
# Out:
#       Rows  Cols  n_binary  n_character  n_factor  n_logical  n_numeric
# 0      601     9         2            0         2          0          7
# 1       80     2         0            0         0          0          2
# 2      474     4         2            0         3          0          1
# 3       31     5         0            0         0          0          5
# 4       60     2         0            0         0          0          2
# ...    ...   ...       ...          ...       ...        ...        ...
# 1709    25     3         0            0         2          0          1
# 1710    32     4         1            0         3          0          1
# 1711   280     4         1            0         2          0          2
# 1712    11     2         0            0         1          0          1
# 1713    11     2         0            0         1          0          1
#
# [1714 rows x 7 columns]
